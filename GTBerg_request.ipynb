# %%
import csv
import os
import re
import requests
from bs4 import BeautifulSoup


def remove_english_charaters(text):
    """
    Remove English characters from text.

    Args:
    text(str):Input text to clean.

    Returns:
    str: Cleaned text with only Chinese characters.
    """    
    cleaned_text = re.sub(r'[a-zA-Z\s\-:.,]+', '', text).strip()
    return cleaned_text


def check_chinese_characters(text):
    """
    Check if the text contains Chinese characters.

    Args:
    text(str):Input text to check.

    Returns:
    bool:True if text contains Chinese characters, False otherwise.
    """
    return bool(re.search(r'[\u4e00-\u9fff]', text))


def scrape_gutenberg_content(id_number):
    """
    Scrape content from Project Gutenberg book which written in Chinese.
    And save it as .txt file.

    Args:
    id_number:book ID number from Project Gutenberg.

    Returns:
    bool: True if successful, False otherwise.
    """
    url = (
        f"https://www.gutenberg.org/cache/epub/{id_number}/"
        f"pg{id_number}-images.html"
    )

    try:
        response = requests.get(url, timeout=10)
        
        #404 errors
        if response.status_code == 404:
            print(f"Error 404: Page not found for ID {id_number}")
            return False

        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract title and clean it
        title_element = soup.select_one('span#pg-title-no-subtitle')
        if not title_element:
            print(f"No title found for ID {id_number}")
            return False

        title = title_element.get_text(strip=True)
        cleaned_title = remove_english_charaters(title)

        # Skip if no Chinese characters in title
        if not check_chinese_characters(cleaned_title):
            print(f"No Chinese characters in title for ID {id_number}")
            return False

        #Extract content paragraphs
        paragraphs = []
        chinese_paragraph_count = 0
        for i in range(1, 100):
            paragraph_id = f'p#id{str(i).zfill(5)}'
            paragraph_element = soup.select_one(paragraph_id)
            
            #Break if no more paragraphs
            if not paragraph_element:
                break
            
            #Remove English characters
            text = paragraph_element.get_text(strip=False)
            text_without_english = re.sub(r'[a-zA-Z]', '', text)
            
            # 只保留包含中文字的段落
            if check_chinese_characters(text_without_english):
                paragraphs.append(text_without_english.strip())
                chinese_paragraph_count += 1      

        #Join paragraphs with double newline
        content = '\n\n'.join(paragraphs)

        #Ensure output directory exists
        os.makedirs('./project_gutenberg', exist_ok=True)

        #Save to txt file
        output_path = os.path.join('./project_gutenberg', f'{cleaned_title}.txt')
        with open(output_path, 'w', encoding='utf-8') as f:
            f.write(content)

        print(f"文件已成功保存: {output_path}")
        return True

    except requests.RequestException as e:
        print(f"Request error for ID {id_number}: {e}")
        return False
    except Exception as e:
        print(f"Unexpected error for ID {id_number}: {e}")
        return False


def process_csv(csv_path):
    """
    Read book ID from CSV and scrape content for each book.

    Args:
    csv_path(str):Path to the CSV containing book ID.
    """
    successful_downloads = 0
    total_attempts = 0

    with open(csv_path, 'r', encoding='utf-8') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            id_number = row[0]
            total_attempts += 1
            
            if scrape_gutenberg_content(id_number):
                successful_downloads += 1

    print(f"\n下載總結:")
    print(f"總嘗試數: {total_attempts}")
    print(f"成功下載: {successful_downloads}")
    print(f"失敗數: {total_attempts - successful_downloads}")


def main():
    """Main function to execute the book scraping process."""
    csv_path = './book_ids.csv'
    process_csv(csv_path)


if __name__ == '__main__':
    main()
# Out:
# 文件已成功保存: ./project_gutenberg\管子.txt
# 文件已成功保存: ./project_gutenberg\虬髯客傳.txt
txt
# 文件已成功保存: ./project_gutenberg\粉妝樓全傳.txt
# 文件已成功保存: ./project_gutenberg\玉支机.txt
# 文件已成功保存: ./project_gutenberg\水調歌頭.txt
# 文件已成功保存: ./project_gutenberg\豆棚閒話.txt
# 文件已成功保存: ./project_gutenberg\本草備要.txt
# 文件已成功保存: ./project_gutenberg\天妃顯聖錄.txt
# 文件已成功保存: ./project_gutenberg\五色石.txt
# 文件已成功保存: ./project_gutenberg\灵历集光.txt
# 文件已成功保存: ./project_gutenberg\黄帝宅經.txt
# 文件已成功保存: ./project_gutenberg\韓詩外傳34.txt
# 文件已成功保存: ./project_gutenberg\官場現形記.txt
# 文件已成功保存: ./project_gutenberg\西海紀遊草.txt
# No Chinese characters in title for ID 4094
# 文件已成功保存: ./project_gutenberg\甌北詩話.txt
# 文件已成功保存: ./project_gutenberg\方言.txt
# 文件已成功保存: ./project_gutenberg\公墓.txt
# 文件已成功保存: ./project_gutenberg\警悟鐘.txt
# 文件已成功保存: ./project_gutenberg\青箱雜記.txt
# 文件已成功保存: ./project_gutenberg\玉梨魂.txt
# 文件已成功保存: ./project_gutenberg\公孫龍子.txt
# 文件已成功保存: ./project_gutenberg\粉妝樓.txt
# 文件已成功保存: ./project_gutenberg\老子.txt
# 文件已成功保存: ./project_gutenberg\蘭花夢奇傳.txt
# 文件已成功保存: ./project_gutenberg\西京雜記.txt
# 文件已成功保存: ./project_gutenberg\尉繚子.txt
# 文件已成功保存: ./project_gutenberg\錦香亭.txt
# 文件已成功保存: ./project_gutenberg\滬語開路=.txt
# 文件已成功保存: ./project_gutenberg\文子.txt
# 文件已成功保存: ./project_gutenberg\粉妝樓6170回.txt
# 文件已成功保存: ./project_gutenberg\燕丹子.txt
# 文件已成功保存: ./project_gutenberg\醒夢駢言.txt
# 文件已成功保存: ./project_gutenberg\韓詩外傳12.txt
# 文件已成功保存: ./project_gutenberg\菜根譚.txt
# 文件已成功保存: ./project_gutenberg\搜神後記.txt
# 文件已成功保存: ./project_gutenberg\後西游記.txt
# 文件已成功保存: ./project_gutenberg\孝經.txt
# 文件已成功保存: ./project_gutenberg\浮生六記.txt
# 文件已成功保存: ./project_gutenberg\遊仙窟.txt
# 文件已成功保存: ./project_gutenberg\南部新書.txt
# 文件已成功保存: ./project_gutenberg\蘇洵集.txt
# 文件已成功保存: ./project_gutenberg\傷寒論.txt
# 文件已成功保存: ./project_gutenberg\抱朴子.txt
# 文件已成功保存: ./project_gutenberg\麟兒報.txt
# 文件已成功保存: ./project_gutenberg\中國小說史略.txt
# 文件已成功保存: ./project_gutenberg\臺灣外紀.txt
# 文件已成功保存: ./project_gutenberg\搜神記1114.txt
# 文件已成功保存: ./project_gutenberg\隋唐嘉話.txt
# 文件已成功保存: ./project_gutenberg\玉雙魚.txt
# 文件已成功保存: ./project_gutenberg\珍珠舶.txt
# No Chinese characters in title for ID 49965
# 文件已成功保存: ./project_gutenberg\夢溪筆談1721.txt
# 文件已成功保存: ./project_gutenberg\癡人說夢記.txt
# 文件已成功保存: ./project_gutenberg\說苑.txt
# No Chinese characters in title for ID 38585
# 文件已成功保存: ./project_gutenberg\花外集.txt
# 文件已成功保存: ./project_gutenberg\夢溪筆談2226.txt
# 文件已成功保存: ./project_gutenberg\老殘遊記.txt
# 文件已成功保存: ./project_gutenberg\二十年目睹之怪現狀.txt
# No Chinese characters in title for ID 2090
# 文件已成功保存: ./project_gutenberg\長生殿.txt
# 文件已成功保存: ./project_gutenberg\鬼谷四友志.txt
# 文件已成功保存: ./project_gutenberg\史記.txt
# 文件已成功保存: ./project_gutenberg\搜神記.txt
# 文件已成功保存: ./project_gutenberg\東坡樂府.txt
# 文件已成功保存: ./project_gutenberg\粉妝樓4150回.txt
# 文件已成功保存: ./project_gutenberg\商子.txt
# 文件已成功保存: ./project_gutenberg\古文觀止.txt
# 文件已成功保存: ./project_gutenberg\舊唐書.txt
# 文件已成功保存: ./project_gutenberg\琵琶記.txt
# 文件已成功保存: ./project_gutenberg\孫子兵法.txt
# 文件已成功保存: ./project_gutenberg\韩非子.txt
# 文件已成功保存: ./project_gutenberg\朱子治家格言.txt
# 文件已成功保存: ./project_gutenberg\初刻拍案驚奇.txt
# 文件已成功保存: ./project_gutenberg\玉蟾記.txt
# 文件已成功保存: ./project_gutenberg\蜃樓志.txt
# 文件已成功保存: ./project_gutenberg\拾遺記.txt
# 文件已成功保存: ./project_gutenberg\管子—0115.txt
# 文件已成功保存: ./project_gutenberg\論衡.txt
# 文件已成功保存: ./project_gutenberg\說苑14.txt
# 文件已成功保存: ./project_gutenberg\南腔北調集.txt
# 文件已成功保存: ./project_gutenberg\明月台.txt
# 文件已成功保存: ./project_gutenberg\說苑58.txt
# 文件已成功保存: ./project_gutenberg\古詩十九首.txt
# 文件已成功保存: ./project_gutenberg\瀛涯勝覽.txt
# 文件已成功保存: ./project_gutenberg\日知錄.txt
# 文件已成功保存: ./project_gutenberg\合浦珠.txt
# 文件已成功保存: ./project_gutenberg\幽夢影—2.txt
# 文件已成功保存: ./project_gutenberg\老殘遊記.txt
# 文件已成功保存: ./project_gutenberg\竇娥冤.txt
# 文件已成功保存: ./project_gutenberg\六一詞.txt
# 文件已成功保存: ./project_gutenberg\圍爐夜話.txt
# 文件已成功保存: ./project_gutenberg\三國志.txt
# 文件已成功保存: ./project_gutenberg\兵法(īǎ).txt
# 文件已成功保存: ./project_gutenberg\石點頭.txt
# 文件已成功保存: ./project_gutenberg\枕中記.txt
# 文件已成功保存: ./project_gutenberg\三俠五義.txt
# 文件已成功保存: ./project_gutenberg\詩經.txt
# 文件已成功保存: ./project_gutenberg\閒情偶寄.txt
# 文件已成功保存: ./project_gutenberg\西湖佳話.txt
# 文件已成功保存: ./project_gutenberg\池北偶談.txt
# 文件已成功保存: ./project_gutenberg\傳習錄.txt
# 文件已成功保存: ./project_gutenberg\說苑912.txt
# 文件已成功保存: ./project_gutenberg\天工開物.txt
# 文件已成功保存: ./project_gutenberg\韓湘子全傳.txt
# 文件已成功保存: ./project_gutenberg\李娃傳.txt
# 文件已成功保存: ./project_gutenberg\宋史.txt
# 文件已成功保存: ./project_gutenberg\人間樂.txt
# 文件已成功保存: ./project_gutenberg\洛神賦.txt
# 文件已成功保存: ./project_gutenberg\楊家將.txt
# 文件已成功保存: ./project_gutenberg\儒林外史.txt
# 文件已成功保存: ./project_gutenberg\筠州黃檗山斷際禪師傳法心要.txt
# 文件已成功保存: ./project_gutenberg\粉妝樓3140回.txt
# 文件已成功保存: ./project_gutenberg\括異志.txt
# 文件已成功保存: ./project_gutenberg\郁離子.txt
# 文件已成功保存: ./project_gutenberg\幼學瓊林.txt
# 文件已成功保存: ./project_gutenberg\喻世明言.txt
# 文件已成功保存: ./project_gutenberg\施公案.txt
# 文件已成功保存: ./project_gutenberg\吳越春秋.txt
# 文件已成功保存: ./project_gutenberg\快士傳.txt
# 文件已成功保存: ./project_gutenberg\引鳳蕭.txt
# 文件已成功保存: ./project_gutenberg\西京雜記.txt
# 文件已成功保存: ./project_gutenberg\搜神記1517.txt
# 文件已成功保存: ./project_gutenberg\鄰女語.txt
# 文件已成功保存: ./project_gutenberg\三字經.txt
# 文件已成功保存: ./project_gutenberg\綠牡丹.txt
# 文件已成功保存: ./project_gutenberg\禮記.txt
# 文件已成功保存: ./project_gutenberg\列女傳.txt
# 文件已成功保存: ./project_gutenberg\醒世姻緣.txt
# 文件已成功保存: ./project_gutenberg\歐遊雜記.txt
# 文件已成功保存: ./project_gutenberg\二刻拍案惊奇.txt
# 文件已成功保存: ./project_gutenberg\申鑒.txt
# 文件已成功保存: ./project_gutenberg\飛跎全傳.txt
# 文件已成功保存: ./project_gutenberg\水滸傳.txt
# 文件已成功保存: ./project_gutenberg\大學章句.txt
# 文件已成功保存: ./project_gutenberg\唐鍾馗平鬼傳.txt
# 文件已成功保存: ./project_gutenberg\梁公九諫.txt
# 文件已成功保存: ./project_gutenberg\列仙傳.txt
# 文件已成功保存: ./project_gutenberg\東京夢華錄.txt
# 文件已成功保存: ./project_gutenberg\牡丹亭.txt
# 文件已成功保存: ./project_gutenberg\夢中緣.txt
# 文件已成功保存: ./project_gutenberg\玉嬌梨.txt
# 文件已成功保存: ./project_gutenberg\狂人日記.txt
# 文件已成功保存: ./project_gutenberg\周禮.txt
# 文件已成功保存: ./project_gutenberg\朝花夕拾.txt
# 文件已成功保存: ./project_gutenberg\孔叢子.txt
# 文件已成功保存: ./project_gutenberg\文中子中說.txt
# 文件已成功保存: ./project_gutenberg\醒世恆言.txt
# 文件已成功保存: ./project_gutenberg\夢溪筆談0710.txt
# 文件已成功保存: ./project_gutenberg\出師表.txt
# 文件已成功保存: ./project_gutenberg\常言道.txt
# 文件已成功保存: ./project_gutenberg\搜神記1820.txt
# 文件已成功保存: ./project_gutenberg\顔氏家訓.txt
# 文件已成功保存: ./project_gutenberg\天豹圖.txt
# 文件已成功保存: ./project_gutenberg\花月痕.txt
# 文件已成功保存: ./project_gutenberg\老殘遊記續集.txt
# 文件已成功保存: ./project_gutenberg\海公案.txt
# 文件已成功保存: ./project_gutenberg\官場現形記.txt
# 文件已成功保存: ./project_gutenberg\蕩寇志.txt
# 文件已成功保存: ./project_gutenberg\沉沦.txt
# 文件已成功保存: ./project_gutenberg\大唐新語.txt
# 文件已成功保存: ./project_gutenberg\補紅樓夢.txt
# 文件已成功保存: ./project_gutenberg\孟子字義疏證.txt
# 文件已成功保存: ./project_gutenberg\豐收.txt
# 文件已成功保存: ./project_gutenberg\粉妝樓7180回.txt
# 文件已成功保存: ./project_gutenberg\醉醒石.txt
# 文件已成功保存: ./project_gutenberg\山水小牘.txt
# 文件已成功保存: ./project_gutenberg\紅樓夢.txt
# 文件已成功保存: ./project_gutenberg\三國志演義.txt
# 文件已成功保存: ./project_gutenberg\管子—02610.txt
# 文件已成功保存: ./project_gutenberg\玉壺淸話.txt
# 文件已成功保存: ./project_gutenberg\滄浪詩話.txt
# 文件已成功保存: ./project_gutenberg\九尾狐.txt
# 文件已成功保存: ./project_gutenberg\飛龍全傳.txt
# 文件已成功保存: ./project_gutenberg\轟天雷.txt
# 文件已成功保存: ./project_gutenberg\鬼谷子.txt
# 文件已成功保存: ./project_gutenberg\駐春園小史.txt
# 文件已成功保存: ./project_gutenberg\何典.txt
# 文件已成功保存: ./project_gutenberg\桃花扇.txt
# No Chinese characters in title for ID 38580
# 文件已成功保存: ./project_gutenberg\幽閨記.txt
# 文件已成功保存: ./project_gutenberg\春秋配.txt
# 文件已成功保存: ./project_gutenberg\胡涂世界.txt
# 文件已成功保存: ./project_gutenberg\孟子.txt
# 文件已成功保存: ./project_gutenberg\白圭志.txt
# 文件已成功保存: ./project_gutenberg\三略.txt
# 文件已成功保存: ./project_gutenberg\狄公案.txt
# 文件已成功保存: ./project_gutenberg\千字文.txt
# 文件已成功保存: ./project_gutenberg\千字文.txt
# 文件已成功保存: ./project_gutenberg\韓詩外傳.txt
# 文件已成功保存: ./project_gutenberg\合錦回文傳.txt
# 文件已成功保存: ./project_gutenberg\新序.txt
# 文件已成功保存: ./project_gutenberg\關尹子.txt
# 文件已成功保存: ./project_gutenberg\荀子集解.txt
# 文件已成功保存: ./project_gutenberg\星槎勝覽.txt
# 文件已成功保存: ./project_gutenberg\九命奇冤.txt
# 文件已成功保存: ./project_gutenberg\海島算經.txt
# 文件已成功保存: ./project_gutenberg\封氏聞見記.txt
# No Chinese characters in title for ID 27016
# 文件已成功保存: ./project_gutenberg\負曝閒談.txt
# 文件已成功保存: ./project_gutenberg\李太白集.txt
# 文件已成功保存: ./project_gutenberg\巧聯珠.txt
# 文件已成功保存: ./project_gutenberg\恨海.txt
# 文件已成功保存: ./project_gutenberg\鬼谷子.txt
# 文件已成功保存: ./project_gutenberg\瀛涯勝覽.txt
# 文件已成功保存: ./project_gutenberg\戲中戲.txt
# 文件已成功保存: ./project_gutenberg\金瓶梅.txt
# 文件已成功保存: ./project_gutenberg\庚巳編.txt
# 文件已成功保存: ./project_gutenberg\貞觀政要.txt
# 文件已成功保存: ./project_gutenberg\佛說無量壽經.txt
# 文件已成功保存: ./project_gutenberg\分甘余話.txt
# 文件已成功保存: ./project_gutenberg\三字經.txt
# 文件已成功保存: ./project_gutenberg\近思錄.txt
# 文件已成功保存: ./project_gutenberg\國語.txt
# 文件已成功保存: ./project_gutenberg\竹齋集.txt
# 文件已成功保存: ./project_gutenberg\桯史.txt
# 文件已成功保存: ./project_gutenberg\老學庵筆記.txt
# 文件已成功保存: ./project_gutenberg\人物志.txt
# 文件已成功保存: ./project_gutenberg\歡喜冤家.txt
# 文件已成功保存: ./project_gutenberg\東坡志林.txt
# 文件已成功保存: ./project_gutenberg\長恨歌.txt
# 文件已成功保存: ./project_gutenberg\漢宮秋.txt
# 文件已成功保存: ./project_gutenberg\一枕奇.txt
# 文件已成功保存: ./project_gutenberg\說苑1316.txt
# 文件已成功保存: ./project_gutenberg\顔氏家訓.txt
# 文件已成功保存: ./project_gutenberg\九命奇冤.txt
# 文件已成功保存: ./project_gutenberg\風月鑒.txt
# 文件已成功保存: ./project_gutenberg\今古奇觀.txt
# 文件已成功保存: ./project_gutenberg\玉台新詠.txt
# No Chinese characters in title for ID 27087
# 文件已成功保存: ./project_gutenberg\玉樓春.txt
# 文件已成功保存: ./project_gutenberg\無聲戲.txt
# 文件已成功保存: ./project_gutenberg\列子.txt
# 文件已成功保存: ./project_gutenberg\狐狸緣全傳.txt
# 文件已成功保存: ./project_gutenberg\雞肋編.txt
# 文件已成功保存: ./project_gutenberg\比目魚.txt
# 文件已成功保存: ./project_gutenberg\尹文子.txt
# 文件已成功保存: ./project_gutenberg\魏鄭公諫錄.txt
# 文件已成功保存: ./project_gutenberg\彭公案.txt
# 文件已成功保存: ./project_gutenberg\竹書紀年.txt
# 文件已成功保存: ./project_gutenberg\黃繡球.txt
# 文件已成功保存: ./project_gutenberg\佛說四十二章經.txt
# 文件已成功保存: ./project_gutenberg\搜神記13.txt
# 文件已成功保存: ./project_gutenberg\杜騙新書.txt
# 文件已成功保存: ./project_gutenberg\大唐三藏取經詩話.txt
# 文件已成功保存: ./project_gutenberg\賈誼新書.txt
# 文件已成功保存: ./project_gutenberg\韓詩外傳910.txt
# 文件已成功保存: ./project_gutenberg\情變.txt
# 文件已成功保存: ./project_gutenberg\清代野记.txt
# 文件已成功保存: ./project_gutenberg\海遊記.txt
# 文件已成功保存: ./project_gutenberg\歸田錄.txt
# 文件已成功保存: ./project_gutenberg\花間集.txt
# 文件已成功保存: ./project_gutenberg\諧鐸.txt
# 文件已成功保存: ./project_gutenberg\明鏡公案.txt
# 文件已成功保存: ./project_gutenberg\飲水詞集.txt
# 文件已成功保存: ./project_gutenberg\粉妝樓110回.txt
# 文件已成功保存: ./project_gutenberg\龍川詞.txt
# 文件已成功保存: ./project_gutenberg\冷眼观.txt
# 文件已成功保存: ./project_gutenberg\夢溪筆談0126.txt
# 文件已成功保存: ./project_gutenberg\人間詞話.txt
# 文件已成功保存: ./project_gutenberg\竹葉亭雜記.txt
# 文件已成功保存: ./project_gutenberg\雙鳳奇緣.txt
# 文件已成功保存: ./project_gutenberg\御製廣寒殿記.txt
# 文件已成功保存: ./project_gutenberg\耳食錄.txt
# 文件已成功保存: ./project_gutenberg\官場現形記.txt
# 文件已成功保存: ./project_gutenberg\癡人說夢記.txt
# 文件已成功保存: ./project_gutenberg\呻吟語.txt
# 文件已成功保存: ./project_gutenberg\左傳.txt
# 文件已成功保存: ./project_gutenberg\商界現形記.txt
# 文件已成功保存: ./project_gutenberg\續子不語.txt
# 文件已成功保存: ./project_gutenberg\二刻拍案驚奇.txt
# 文件已成功保存: ./project_gutenberg\燕子箋.txt
# 文件已成功保存: ./project_gutenberg\五孝傳.txt
# 文件已成功保存: ./project_gutenberg\竇娥寃.txt
# 文件已成功保存: ./project_gutenberg\幽夢影.txt
# 文件已成功保存: ./project_gutenberg\孫子算經.txt
# 文件已成功保存: ./project_gutenberg\搜神記410.txt
# 文件已成功保存: ./project_gutenberg\文心雕龍.txt
# 文件已成功保存: ./project_gutenberg\幻中游.txt
# 文件已成功保存: ./project_gutenberg\徐霞客遊記.txt
# 文件已成功保存: ./project_gutenberg\茶經.txt
# 文件已成功保存: ./project_gutenberg\安樂集.txt
# 文件已成功保存: ./project_gutenberg\西遊記.txt
# 文件已成功保存: ./project_gutenberg\遊仙窟.txt
# 文件已成功保存: ./project_gutenberg\續世說.txt
# 文件已成功保存: ./project_gutenberg\海上花列傳.txt
# 文件已成功保存: ./project_gutenberg\野草.txt
# 文件已成功保存: ./project_gutenberg\斬鬼傳.txt
# 文件已成功保存: ./project_gutenberg\顔氏家訓—0506.txt
# 文件已成功保存: ./project_gutenberg\五鳳吟.txt
# 文件已成功保存: ./project_gutenberg\商君書.txt
# 文件已成功保存: ./project_gutenberg\青樓夢.txt
# 文件已成功保存: ./project_gutenberg\山海經.txt
# 文件已成功保存: ./project_gutenberg\吳船錄.txt
# 文件已成功保存: ./project_gutenberg\孽海花.txt
# 文件已成功保存: ./project_gutenberg\金剛般若波羅蜜經.txt
# 文件已成功保存: ./project_gutenberg\張載集.txt
# 文件已成功保存: ./project_gutenberg\道德經.txt
# 文件已成功保存: ./project_gutenberg\金雲翹傳.txt
# 文件已成功保存: ./project_gutenberg\夢溪筆談.txt
# 文件已成功保存: ./project_gutenberg\高士傳.txt
# 文件已成功保存: ./project_gutenberg\唐才子傳.txt
# 文件已成功保存: ./project_gutenberg\牛郎織女傳.txt
# 文件已成功保存: ./project_gutenberg\治世餘聞.txt
# 文件已成功保存: ./project_gutenberg\顔氏家訓.txt
# 文件已成功保存: ./project_gutenberg\顔氏家訓—07.txt
# 文件已成功保存: ./project_gutenberg\文明小史.txt
# 文件已成功保存: ./project_gutenberg\李義山詩集.txt
# 文件已成功保存: ./project_gutenberg\平妖傳.txt
# 文件已成功保存: ./project_gutenberg\粉妝樓2130回.txt
# 文件已成功保存: ./project_gutenberg\周髀算經.txt
# 文件已成功保存: ./project_gutenberg\楊家將.txt
# 文件已成功保存: ./project_gutenberg\聊齋志異.txt
# 文件已成功保存: ./project_gutenberg\裨海紀遊.txt
# 文件已成功保存: ./project_gutenberg\阿Ｑ正傳.txt
# 文件已成功保存: ./project_gutenberg\漱玉詞.txt
# 文件已成功保存: ./project_gutenberg\唐诗三百首.txt
# 文件已成功保存: ./project_gutenberg\畫圖緣.txt
# 文件已成功保存: ./project_gutenberg\斷鴻零雁記.txt
# 文件已成功保存: ./project_gutenberg\瞎騙奇聞.txt
# No Chinese characters in title for ID 54820
# 文件已成功保存: ./project_gutenberg\癡人福.txt
# No Chinese characters in title for ID 27060
# 文件已成功保存: ./project_gutenberg\肉蒲團.txt
# 文件已成功保存: ./project_gutenberg\夜雨秋燈錄.txt
# 文件已成功保存: ./project_gutenberg\闲情偶寄.txt
# 文件已成功保存: ./project_gutenberg\弟子規.txt
# 文件已成功保存: ./project_gutenberg\定情人.txt
# 文件已成功保存: ./project_gutenberg\蕉葉帕.txt
# 文件已成功保存: ./project_gutenberg\木蘭奇女傳.txt
# 文件已成功保存: ./project_gutenberg\西湖夢尋.txt
# 文件已成功保存: ./project_gutenberg\論語.txt
# 文件已成功保存: ./project_gutenberg\滿江紅.txt
#
# 下載總結:
# 總嘗試數: 444
# 成功下載: 432
# 失敗數: 12
